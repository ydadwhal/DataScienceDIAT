# %% [markdown]
# ###Matplotlib

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
plt.style.use('seaborn-white')

import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
#plt.style.use('_mpl-gallery')

# make data:
np.random.seed(10)
D = np.random.normal((3, 5, 4), (1.25, 1.00, 1.25), (100, 3))

# plot
fig, ax = plt.subplots()
VP = ax.boxplot(D, positions=[2, 4, 6], widths=1.5, patch_artist=True,
                showmeans=False, showfliers=False,
                medianprops={"color": "white", "linewidth": 0.5},
                boxprops={"facecolor": "C0", "edgecolor": "white",
                          "linewidth": 0.5},
                whiskerprops={"color": "C0", "linewidth": 1.5},
                capprops={"color": "C0", "linewidth": 1.5})

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
a=np.linspace(0,10,100)

# %%
a
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
fig=plt.figure()
ax=plt.axis()
plt.plot(a,np.sin(a)+2*np.cos(a),':',color=(0.5,0.1,0.9),label='fxn1')
plt.plot(a,np.sin(a),linestyle='--',color='red',label='fxn2')
plt.plot(a,np.cos(a),linestyle='-.',color='g',label='fxn3')
plt.plot(a,np.cos(a+20),':c')
#plt.xlim(2,8)
#plt.ylim(-1,1.5)
#plt.axis([2,8,-1,1.5])
plt.axis('equal')
plt.title("My first plot in python")
plt.xlabel("a")
plt.ylabel("fxn")
plt.legend()

# %%
fig.savefig('myfirstfig.jpeg')

# %%
data1=np.random.rand(5)
data2=np.random.rand(5)

# %%
plt.scatter(data1,data2,marker='>')

# %%
for marker in ['.','o','v','x','>','<','s','d',',','+']:
  plt.plot(np.random.rand(5),np.random.rand(5),marker, label="marker='{0}'".format(marker),markersize=7
           #,markerfacecolor='blue',markeredgecolor='red'
           )

plt.title('My Second Plot')
plt.legend()

# %%
for marker in ['.','o','v','x','>','<','s','d',',','+']:
  plt.scatter(np.random.rand(5),np.random.rand(5),)

# %%
plt.scatter(np.random.rand(50),np.random.rand(50),c=np.random.rand(50),s=500*np.random.rand(50),alpha=0.4)

# %%
x=np.linspace(0,10,50)

# %%
dy=0.8
y=np.sin(x)+dy*np.random.randn(50)

plt.errorbar(x,y,yerr=dy,fmt='.k');

# %%
plt.errorbar(x,y,yerr=dy,fmt='o',ecolor='lightgray', elinewidth=2, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
a=lambda x:x*np.sin(x)
xdata=np.array([1,2,3,5,8])
ydata=a(xdata)

# %%
def mean_sq_error(true,pred):
  return(((true-pred)**2).sum()/len(true-pred))

# %%
gp.fit(xdata[:,np.newaxis],ydata)
xfit=np.linspace(0,10,1000)
yfit= gp.predict(xfit[:,np.newaxis])
MSE=mean_sq_error(a(xfit),yfit)
dyfit=2*np.sqrt(MSE)

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
gp=GaussianProcessRegressor()

# %%
plt.plot(xdata,ydata,'or')
plt.plot(xfit,yfit,'-',color='gray')
plt.fill_between(xfit,yfit,yfit-dyfit,yfit+dyfit, color='gray',alpha=0.25)

# %%
def f(x,y):
  return  np.sin(x) ** 10 +np.cos(10+y*x)*np.cos(x)

# %%
x=np.linspace(0,5,50)
y=np.linspace(0,5,40)

# %%
X,Y=np.meshgrid(x,y)
Z=f(X,Y)

# %%
plt.contour(X,Y,Z,colors='black')

# %%
plt.contour(X,Y,Z,cmap='RdGy')

# %%
plt.contour(X,Y,Z,20,cmap='RdGy')

# %%
plt.contour(X,Y,Z,40,cmap='RdGy')

# %%
plt.contour(X,Y,Z,20,cmap='RdGy')
plt.colorbar()

# %%
contours=plt.contour(X,Y,Z,5,cmap='RdGy')

plt.clabel(contours,inline=True,fontsize=8)
plt.colorbar()

# %%
data1=np.random.randn(1000)
data2=np.random.normal(0,0.8,1000)
data3=np.random.normal(-2,1,1000)
data4=np.random.normal(3,2,1000)

# %%
plt.hist(data1)
# Out:
# (array([  3.,  10.,  47., 147., 199., 238., 194., 109.,  40.,  13.]),
#  array([-3.31766905, -2.70658557, -2.09550209, -1.48441861, -0.87333513,
#         -0.26225165,  0.34883184,  0.95991532,  1.5709988 ,  2.18208228,
#          2.79316576]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data1, bins=30,alpha=0.5,histtype='stepfilled',color='red',edgecolor='black')
# Out:
# (array([ 1.,  1.,  1.,  1.,  7.,  2.,  9., 17., 21., 39., 46., 62., 43.,
#         72., 84., 93., 64., 81., 81., 65., 48., 48., 31., 30., 16., 10.,
#         14.,  8.,  3.,  2.]),
#  array([-3.31766905, -3.11397456, -2.91028006, -2.70658557, -2.50289108,
#         -2.29919658, -2.09550209, -1.8918076 , -1.6881131 , -1.48441861,
#         -1.28072411, -1.07702962, -0.87333513, -0.66964063, -0.46594614,
#         -0.26225165, -0.05855715,  0.14513734,  0.34883184,  0.55252633,
#          0.75622082,  0.95991532,  1.16360981,  1.36730431,  1.5709988 ,
#          1.77469329,  1.97838779,  2.18208228,  2.38577677,  2.58947127,
#          2.79316576]),
#  <a list of 1 Patch objects>)

# %%
plt.hist(data2,bins=30,alpha=0.3,histtype='stepfilled')
plt.hist(data3,bins=30,alpha=0.3,histtype='stepfilled')
plt.hist(data4,bins=30,alpha=0.3,histtype='stepfilled')
# Out:
# (array([ 4.,  5., 10., 14., 24., 19., 30., 37., 55., 60., 71., 82., 79.,
#         80., 72., 81., 64., 57., 54., 34., 14., 20., 12.,  9.,  8.,  2.,
#          1.,  1.,  0.,  1.]),
#  array([-2.59122988, -2.17453255, -1.75783522, -1.3411379 , -0.92444057,
#         -0.50774324, -0.09104591,  0.32565142,  0.74234875,  1.15904607,
#          1.5757434 ,  1.99244073,  2.40913806,  2.82583539,  3.24253271,
#          3.65923004,  4.07592737,  4.4926247 ,  4.90932203,  5.32601936,
#          5.74271668,  6.15941401,  6.57611134,  6.99280867,  7.409506  ,
#          7.82620333,  8.24290065,  8.65959798,  9.07629531,  9.49299264,
#          9.90968997]),
#  <a list of 1 Patch objects>)

# %%
x,y=np.random.multivariate_normal([0,0],[[1,1],[1,2]],10000).T

# %%
plt.hist2d(x,y,bins=30,cmap='Blues')
cb=plt.colorbar()
cb.set_label('counts in the bins')

# %%
plt.hexbin(x,y,gridsize=30,cmap='Blues')
cb=plt.colorbar()
cb.set_label('counts in the bins')

# %%
dict={'A':np.random.randn(365).cumsum(0),
      'B':np.random.randn(365).cumsum(0)+20,
      'C':np.random.randn(365).cumsum(0)-20
      }

# %%
df=pd.DataFrame(dict,index=pd.date_range('1/1/2021',periods=365))

# %%
df.head()
# Out:
#                    A          B          C
# 2021-01-01  0.313788  17.949328 -19.822297
# 2021-01-02  0.266125  16.390749 -20.986380
# 2021-01-03  1.246858  15.160917 -21.291901
# 2021-01-04  1.512459  16.491214 -21.402400
# 2021-01-05  2.016546  16.860422 -20.320829

# %%
df.plot();

# %%
df.plot('A','B',kind='scatter')

# %% [markdown]
#  kind='line'
# 'bar'
# 'barh'
# 'hist'
# 'box'
# 'kde'
# 'density'
# 'area'
# 'pie'
# 'hexbin'
# 'scatter'

# %%
scAB=df.plot.scatter('A','B',c=df['B'],colormap='viridis')
scAB.set_aspect('equal')

# %%
df.plot.box()

# %%
df.plot.hist(alpha=0.5)

# %%
df.plot.kde()

# %% [markdown]
# ###Seaborn

# %%
x=np.linspace(0,10,500)
y=np.cumsum(np.random.randn(500,6),0)

# %%
sns.set()

# %%
plt.plot(x,y)
plt.legend('ABCDEF',ncol=2,loc='upper left')

# %%
data=np.random.multivariate_normal([0,0],[[1,1],[1,2]],2000)
data=pd.DataFrame(data,columns=['x','y'])

# %%
for col in 'xy':
  plt.hist(data[col],alpha=0.5)

# %%
for col in 'xy':
  sns.kdeplot(data[col],alpha=0.5,shade=True)

# %%
sns.distplot(data['x'])
sns.distplot(data['y'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(data['x']);

# %%
with sns.axes_style('white'):
  sns.jointplot('x','y',data, kind='kde')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
iris=sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species',size=2.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
data=pd.read_csv('test_data.csv')

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
newdata=data.dropna(how="any")

# %%
newdata.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
newdata["visibility_scaled"]=newdata['Item_Visibility']*100
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
newdata.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# ...

# %%
sns.lineplot(x='Item_Weight',y='Item_MRP',data=newdata[:50])

# %%
sns.barplot(x='Item_Type',y='Item_MRP',data=newdata[:50])

# %%
sns.distplot(newdata['Item_MRP'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(newdata['Item_Outlet_Sales'],orient="vertical")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
sns.violinplot(newdata['Item_Outlet_Sales'],orient='vertical',color='magenta');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
sns.relplot(x="Item_MRP",y="Item_Outlet_Sales",data=newdata[:200],kind="scatter")

# %%
sns.relplot(x="Item_MRP",y="Item_Outlet_Sales",data=newdata[:200],kind="scatter",hue="Item_Type",size="Item_Weight")

# %%
sns.relplot(x="Item_MRP",y="Item_Outlet_Sales",data=newdata[:200],kind="scatter",hue="Item_Type",size="Item_MRP")

# %%
sns.catplot(x="Outlet_Size",y="Item_Outlet_Sales",kind='strip',data=newdata[:250])

# %%
sns.catplot(x="Outlet_Size",y="Item_Outlet_Sales",kind='swarm',data=newdata[:250])

# %%
sns.catplot(x="Outlet_Size",y="Item_Outlet_Sales",kind='box',data=newdata[:250])
